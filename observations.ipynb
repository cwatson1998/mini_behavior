# %%
import gymnasium as gym
from minigrid.wrappers import ImgObsWrapper, RGBImgObsWrapper, RGBImgPartialObsWrapper, FullyObsWrapper
from mini_behavior.utils.wrappers import MiniBHFullyObsWrapper
from mini_behavior.register import register
import mini_behavior
import numpy as np
from PIL import Image
# Out:
# /home/christopher/miniconda3/envs/mini-behavior/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /home/christopher/miniconda3/envs/mini-behavior/lib/python3.10/site-packages/gym/envs/registration.py:307: DeprecationWarning: The package name gym_minigrid has been deprecated in favor of minigrid. Please uninstall gym_minigrid and install minigrid with `pip install minigrid`. Future releases will be maintained under the new package name minigrid.
#   fn()

# %%
env_name = 'MiniGrid-InstallingAPrinter-16x16-N2-v0'
#env_name = 'MiniGrid-InstallingAPrinter-8x8-N2-v0'
#env_name = 'MiniGrid-SortingBooks-16x16-N2-v0'
env_name = 'MiniGrid-CleaningShoes-16x16-N2-v0'
env = gym.make(env_name)
env.set_wrapper_attr('tile_size', 8)
#env = RGBImgObsWrapper(env)
env = RGBImgObsWrapper(env, tile_size=84)
print(env.observation_space)
print(env.action_space)
actions_list = list(env.get_wrapper_attr('actions'))
print(actions_list)

obs, info = env.reset()
#obs, rew, term, trunc, info = env.step(2)
# Out:
# /home/christopher/miniconda3/envs/mini-behavior/lib/python3.10/site-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment MiniGrid-CleaningShoes-16x16-N2-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Dict('direction': Discrete(4), 'image': Box(0, 255, (672, 672, 3), uint8), 'mission': MissionSpace(<function MiniBehaviorEnv._gen_mission at 0x783fbfce4c10>, None))
# Discrete(15)
# [<Actions.left: 0>, <Actions.right: 1>, <Actions.forward: 2>, <Actions.toggle: 3>, <Actions.open: 4>, <Actions.close: 5>, <Actions.slice: 6>, <Actions.cook: 7>, <Actions.drop_in: 8>, <Actions.pickup_0: 9>, <Actions.pickup_1: 10>, <Actions.pickup_2: 11>, <Actions.drop_0: 12>, <Actions.drop_1: 13>, <Actions.drop_2: 14>]
# Debug, grid state_values:
# ...

# %%
env.render()
# Out:
# debug. minigrid (the pip package) render called.
# debug. Chris version of. get full render called
# there was no self.cumulative_highligh_mask field
# debug. render_furniture_states called
# debug. we tried to render <mini_behavior.objects.Bed object at 0x7b35b69d34c0>
# debug. we tried to render <mini_behavior.objects.Sink object at 0x7b35b682f940>
# debug: also rendering states as part of render furniture
# debug. MiniBehavior.render_states called.
# None
# debug. render_tile called
# None
# debug. render_tile called
# None
# debug. render_tile called
# array([[[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
# ...

# %%
img = obs['image']
#img = env.unwrapped.get_full_render(highlight=True, tile_size=64)
print(type(img))
print(img.dtype)
print(img.shape)
# MiniGrid-InstallingAPrinter-16x16-N2-v0 gives (7,7,32)
# MiniGrid-InstallingAPrinter-8x8-N2-v0 gives (7,7,32)
display(Image.fromarray(img))
# Out:
# <class 'numpy.ndarray'>
# uint8
# (672, 672, 3)
# <PIL.Image.Image image mode=RGB size=672x672>
